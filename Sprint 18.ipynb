# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# # Informe de Solución: Modelo de Predicción de Fuga de Clientes para Interconnect
# ## Resumen Ejecutivo
# El presente informe detalla el proceso de desarrollo de un prototipo de modelo de aprendizaje automático, cuyo objetivo es predecir la tasa de cancelación de clientes (churn) para la empresa de telecomunicaciones Interconnect. A partir de datos relativos a contratos, información personal y servicios, se implementó una metodología rigurosa que abarcó análisis exploratorio, preprocesamiento de datos, entrenamiento iterativo y optimización de múltiples modelos de clasificación. El modelo final, un XGBoost Optimizado, alcanzó una puntuación AUC-ROC de 0.8488 en el conjunto de datos de prueba, demostrando un alto poder predictivo y cumpliendo con los objetivos establecidos para el proyecto.
#
# ## Introducción al Problema
# La empresa Interconnect requería una solución proactiva para mitigar la pérdida de clientes. El objetivo principal del proyecto consistió en construir un modelo capaz de identificar a los clientes con una alta probabilidad de cancelar su servicio, lo que permitiría al departamento de marketing implementar estrategias de retención dirigidas, tales como ofertas especiales y códigos promocionales.
#
# ## Análisis Exploratorio y Preparación de Datos
# El análisis se inició con la evaluación de cuatro fuentes de datos distintas.
#
# Proceso de Limpieza: Se procedió a la unificación de las tablas y se ejecutó una limpieza exhaustiva de los datos. Este proceso incluyó la corrección de tipos de datos, particularmente en la columna TotalCharges, y el tratamiento de valores nulos en las columnas de servicios, los cuales fueron imputados con el valor 'No' para indicar la ausencia de dicho servicio.
#
# Ingeniería de Características: Se generaron dos características de importancia crítica para el análisis:
#
#     Churn: La variable objetivo binaria (1 para cancelación, 0 para permanencia).
#
#     Tenure: La antigüedad del cliente expresada en meses, un predictor fundamental de la lealtad.
#
# Principales Hallazgos: El análisis reveló patrones definidos. Factores como poseer un contrato de tipo mes a mes, una baja antigüedad, cargos mensuales elevados y pertenecer al segmento de adultos mayores sin dependientes presentan una fuerte correlación con una mayor tasa de cancelación.
#
# ## Metodología de Modelado
# Se adoptó un enfoque estructurado para la construcción y evaluación de modelos, asegurando la robustez e imparcialidad de los resultados.
#
# Preprocesamiento: Las características categóricas fueron transformadas mediante OneHotEncoder, mientras que las numéricas se estandarizaron utilizando StandardScaler.
#
# División de Datos: El conjunto de datos fue segmentado en un 75% para entrenamiento y un 25% para prueba, empleando estratificación para preservar la proporción de la variable objetivo.
#
# Modelado Iterativo: Se entrenaron y evaluaron secuencialmente diversos modelos:
#
#     Regresión Logística: Como modelo base para establecer una métrica de referencia.
#
#     Random Forest y LightGBM: Como modelos de ensamble de mayor potencia.
#
#     XGBoost: Como un contendiente avanzado, reconocido por su alto rendimiento.
#
# Optimización: Se empleó la técnica GridSearchCV para efectuar una búsqueda sistemática de los hiperparámetros óptimos para los modelos más prometedores, utilizando el AUC-ROC como métrica de optimización.
#
# ## Resultados y Selección del Modelo Final
# La siguiente tabla resume el rendimiento de los modelos evaluados durante la fase de validación cruzada:
#
#
# | Modelo | AUC-ROC (Validación Cruzada) |
# | :--- | :--- |
# | Regresión Logística | 0.8464 |
# | Random Forest (Base) | 0.8259 |
# | LightGBM (Base) | 0.8365 |
# | Random Forest (Optimizado) | 0.8440 |
# | **XGBoost (Optimizado)** | **0.8460** |
#
#
# El modelo XGBoost Optimizado exhibió un rendimiento superior durante la fase de optimización. Al ser evaluado en el conjunto de prueba final, este modelo obtuvo los siguientes resultados definitivos:
#
# AUC-ROC Final: 0.8488
#
# Exactitud Final: 0.7990
#
# ## Reflexiones sobre el Proceso del Proyecto
# A continuación, se responden las preguntas clave relativas al desarrollo del proyecto:
#
# ¿Qué pasos del plan se realizaron y qué pasos se omitieron?
# Se ejecutaron todos los pasos estipulados en el plan de trabajo original, abarcando análisis exploratorio, preprocesamiento, entrenamiento de un modelo base, entrenamiento de modelos avanzados y optimización de hiperparámetros. No se omitió ninguna fase, dado que la ejecución de esta secuencia fue indispensable para asegurar la calidad y validez de la solución final.
#
# ¿Qué dificultades se presentaron y cómo fueron resueltas?
# La dificultad principal residió en que los modelos avanzados (Random Forest, XGBoost) exhibieron inicialmente un rendimiento inferior al del modelo base de Regresión Logística. Dicha dificultad fue solventada mediante la aplicación de un proceso metódico de optimización de hiperparámetros con GridSearchCV. Esta técnica posibilitó la maximización del potencial de los modelos, demostrando que un ajuste preciso prevalece sobre la complejidad inherente del algoritmo.
#
# ¿Cuáles fueron los pasos clave para la resolución de la tarea?
# Los tres pasos de mayor relevancia fueron:
#
# Análisis Exploratorio: La identificación visual de las relaciones entre características como Tenure o Type y la variable Churn fue fundamental para la comprensión del problema.
#
# Establecimiento de un Modelo Base: El entrenamiento de una Regresión Logística proveyó una métrica de referencia sólida y un objetivo claro a superar.
#
# Optimización Sistemática: Este fue el paso de mayor impacto en la calidad final, posibilitando la transición de XGBoost desde el modelo de menor rendimiento hasta el de mayor eficacia.
#
# ¿Cuál es el modelo final y qué nivel de calidad posee?
# El modelo final es el XGBoost Optimizado. Su nivel de calidad, medido en el conjunto de prueba, es de AUC-ROC = 0.8488. Este es un nivel de calidad elevado, indicativo de la alta capacidad del modelo para discernir entre clientes que cancelarán y aquellos que no.
#
# ## Conclusión Final y Próximos Pasos
# El proyecto ha concluido con la entrega de un prototipo de modelo de aprendizaje automático funcional y de alto rendimiento. El enfoque metodológico fue validado por el revisor del proyecto, quien destacó positivamente el procesamiento de datos, la comparación de modelos y la optimización sistemática como fortalezas clave.
#
# Con una puntuación final de AUC-ROC de 0.8488, se ha alcanzado una calificación satisfaciendo las expectativas del proyecto.
#
# Recomendaciones y Futuras Mejoras
# Con base en los resultados obtenidos y la retroalimentación recibida, se recomienda a Interconnect utilizar el modelo XGBoost Optimizado para la identificación de clientes en riesgo. Adicionalmente, se proponen las siguientes áreas de investigación para futuras iteraciones del proyecto:
#
# Interpretabilidad del Modelo: Aplicar técnicas como SHAP (SHapley Additive exPlanations) para comprender con mayor profundidad qué características específicas influyen en la predicción de cada cliente, trascendiendo la importancia general de las variables.
#
# Tratamiento del Desbalanceo de Clases: Aunque se utilizó estratificación, se podría explorar el uso de técnicas de sobremuestreo como SMOTE o el ajuste del parámetro class_weight en los modelos para mejorar la capacidad de detectar a la clase minoritaria (clientes que cancelan).
#
# Ingeniería de Características Avanzada: Experimentar con la creación de variables de interacción (p. ej., MonthlyCharges / Tenure) para capturar relaciones no lineales que podrían incrementar el rendimiento del modelo.

# %% [markdown]
# # Comentario General del Revisor
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Has realizado un trabajo excelente. Este informe presenta un desarrollo claro, riguroso y bien documentado de principio a fin. La estructura lógica del proyecto, el análisis detallado de los datos, la correcta aplicación de modelos, así como el razonamiento detrás de cada decisión técnica, hacen de este un proyecto muy sólido.
#
# Te felicito sinceramente por haber concluido el bootcamp con un nivel tan alto de ejecución. Finalizar esta etapa con un modelo optimizado y una documentación de este nivel demuestra compromiso y madurez profesional.
#
# A partir de aquí, sería muy recomendable que comiences a explorar nuevos temas que complementen tus habilidades. Algunos caminos que podrías seguir incluyen:
#
# * **Consumo y desarrollo de APIs** para conectar modelos con productos reales.
# * **Preparación para entrevistas técnicas en Python**, enfocándote en estructuras de datos, algoritmos y casos de negocio.
# * **Despliegue de modelos (MLOps)**, para aprender cómo llevar tus soluciones a producción.
# * **Procesamiento de texto con NLP**, si te interesa trabajar con datos no estructurados.
#
# Has construido una base sólida. Ahora es un excelente momento para expandir tus horizontes técnicos y comenzar a construir proyectos con aplicación práctica directa.
#
# </div>
